# %%
# attempting to make sense of the Hades Game save file (.sav)

# %%
# read save file
# ' , encoding='utf-8' '
with open('Profile3.sav', encoding='utf-8', errors='ignore') as file:
    save = file.read()

    
print(len(save))
# Out:
# 554131

# %%
save[0:40]
# Out:
# 'SGB1\x19\x19\x10\x00\x00\x00rU_\x00\x00\x00\x00\n\x00\x00\x00Location_Home4\x00\x00\x006\x00'

# %%
sav = save
# Out:
# 39

# %%
# sav = sav.replace('\x00', ' ')
print(save)
# sav
# Out:
# SGB1rU_
# Location_Home46
# AmmoMetaUpgradeEnemyCountShrineUpgradeShopPricesShrineUpgradeEnemyDamageShrineUpgradeEnemyHealthShrineUpgrade"
# RushWeapon
# SwordParryRangedWeaponSwordWeaponFishingPointDeathAreaBedroom
# RoomPreRun	THSPlayedRandomTextLines#`SZeusLootBought021SDionysusRejection031SHadesAboutCharon011SThanatosFieldAboutKeepsake011S"MiscStartRepeatable201v
# MakeUp071SCerberusChat05fTheseuL"03BZeusRunCleared01.2ZeuDemeter011SWithAphroditebPoseidRNyx011SArAthena011CHermFbZeus023@"16y>51SPatrocl?#21)achilleS"22=Backstory@TVsMegFuryRunProgress031S
# ...

# %%
# sav

# %%
# save
